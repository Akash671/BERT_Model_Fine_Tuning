# %%
import pandas as pd

# %%
df=pd.read_csv("/content/train.csv")

df.head()
# Out:
#    tweet_id     user_handle            timestamp  \
# 0         1        @user123  2024-11-03 08:45:00
# 1         2    @politicsFan  2024-11-03 09:15:23
# 2         3  @greenAdvocate  2024-11-03 10:05:45
# 3         4     @indieVoice  2024-11-03 11:20:10
# 4         5   @libertyLover  2024-11-03 12:35:55
#
#                                           tweet_text       candidate  \
# 0  Excited to see Kamala Harris leading the Democ...   Kamala Harris
# 1  Donald Trump's policies are the best for our e...    Donald Trump
# 2  Jill Stein's environmental plans are exactly w...      Jill Stein
# 3  Robert Kennedy offers a fresh perspective outs...  Robert Kennedy
# 4  Chase Oliver's libertarian stance promotes tru...    Chase Oliver
#
#                party  retweets  likes sentiment
# 0   Democratic Party       120    450  positive
# 1   Republican Party        85    300  positive
# 2        Green Party        60    200  positive
# 3        Independent        40    150   neutral
# 4  Libertarian Party        30    120  positive

# %%
test_df=pd.read_csv("/content/test.csv")

# %%
df.columns
# Out:
# Index(['tweet_id', 'user_handle', 'timestamp', 'tweet_text', 'candidate',
#        'party', 'retweets', 'likes', 'sentiment'],
#       dtype='object')

# %%
df.head()
# Out:
#    tweet_id     user_handle            timestamp  \
# 0         1        @user123  2024-11-03 08:45:00
# 1         2    @politicsFan  2024-11-03 09:15:23
# 2         3  @greenAdvocate  2024-11-03 10:05:45
# 3         4     @indieVoice  2024-11-03 11:20:10
# 4         5   @libertyLover  2024-11-03 12:35:55
#
#                                           tweet_text       candidate  \
# 0  Excited to see Kamala Harris leading the Democ...   Kamala Harris
# 1  Donald Trump's policies are the best for our e...    Donald Trump
# 2  Jill Stein's environmental plans are exactly w...      Jill Stein
# 3  Robert Kennedy offers a fresh perspective outs...  Robert Kennedy
# 4  Chase Oliver's libertarian stance promotes tru...    Chase Oliver
#
#                party  retweets  likes sentiment
# 0   Democratic Party       120    450  positive
# 1   Republican Party        85    300  positive
# 2        Green Party        60    200  positive
# 3        Independent        40    150   neutral
# 4  Libertarian Party        30    120  positive

# %%
df[['retweets','likes','sentiment']].sample(20)
# Out:
#      retweets  likes sentiment
# 361       110    460  negative
# 73         30    115   neutral
# 374        50    170  positive
# 155        85    330  positive
# 104        50    180  positive
# 394        50    175  positive
# 377        70    230  positive
# 124        35    130  positive
# 68         25    100   neutral
# 450        85    325  positive
# 9          50    180  positive
# 194        35    140  positive
# 406        95    420  positive
# 84         45    150  positive
# 371        80    310  positive
# 388        25    100   neutral
# 495        95    360  positive
# 30         80    310  positive
# 316        95    410  negative
# 408        22     95   neutral

# %%
df.drop(['tweet_id', 'user_handle', 'timestamp', 'candidate', 'retweets', 'likes'],axis=1,inplace=True)

# %%
test_df.drop(['tweet_id', 'user_handle', 'timestamp', 'candidate', 'retweets', 'likes'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                           tweet_text              party  \
# 0  Excited to see Kamala Harris leading the Democ...   Democratic Party
# 1  Donald Trump's policies are the best for our e...   Republican Party
# 2  Jill Stein's environmental plans are exactly w...        Green Party
# 3  Robert Kennedy offers a fresh perspective outs...        Independent
# 4  Chase Oliver's libertarian stance promotes tru...  Libertarian Party
#
#   sentiment
# 0  positive
# 1  positive
# 2  positive
# 3   neutral
# 4  positive

# %%
df.shape
# Out:
# (500, 3)

# %%
for row in range(500):
  df['tweet_text'][row]=df['party'][row]+" "+df['tweet_text'][row]
# Out:
# /tmp/ipython-input-40-3328323599.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tweet_text'][row]=df['party'][row]+" "+df['tweet_text'][row]

# %%
for row in range(50):
  test_df['tweet_text'][row]=test_df['party'][row]+" "+test_df['tweet_text'][row]
# Out:
# /tmp/ipython-input-66-1927596304.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test_df['tweet_text'][row]=test_df['party'][row]+" "+test_df['tweet_text'][row]

# %%
df.head()
# Out:
#                                           tweet_text              party  \
# 0  Democratic Party Excited to see Kamala Harris ...   Democratic Party
# 1  Republican Party Donald Trump's policies are t...   Republican Party
# 2  Green Party Jill Stein's environmental plans a...        Green Party
# 3  Independent Robert Kennedy offers a fresh pers...        Independent
# 4  Libertarian Party Chase Oliver's libertarian s...  Libertarian Party
#
#   sentiment
# 0  positive
# 1  positive
# 2  positive
# 3   neutral
# 4  positive

# %%
df.drop('party',axis=1,inplace=True)

# %%
test_df.drop('party',axis=1,inplace=True)

# %%
df.head()
# Out:
#                                           tweet_text sentiment
# 0  Democratic Party Excited to see Kamala Harris ...  positive
# 1  Republican Party Donald Trump's policies are t...  positive
# 2  Green Party Jill Stein's environmental plans a...  positive
# 3  Independent Robert Kennedy offers a fresh pers...   neutral
# 4  Libertarian Party Chase Oliver's libertarian s...  positive

# %%
import re

def cleaning(data):
  # 1 lower case
  data=data.lower()
  #2 remove html tag
  data=re.sub(r'<.*?>','',data)
  #3 remove urls
  data=re.sub(r'http\S+|www\S+','',data)
  #4 remove emojies
  data=re.sub(r'[^\x00-\x7F]+',' ',data)
  #5 remove punchuations
  data=re.sub(r"[!]{2,}|[?]{2,}|[#]{2,}|[\-]{2,}", " ",data)
  #6 Remove special characters but keep words and basic punctuation
  clean_data = re.sub(r"[^\w\s.,!?]", "", data)

  return clean_data

# %%
df['text']=df['tweet_text'].apply(cleaning)
df.drop('tweet_text',axis=1,inplace=True)

# %%
test_df['text']=test_df['tweet_text'].apply(cleaning)
test_df.drop('tweet_text',axis=1,inplace=True)

# %%
def sentiment_cleaning(row):
  if row=='positive  ':
    return 'positive'
  else:
    return row

# %%
df['sentiment']=df['sentiment'].apply(sentiment_cleaning)

# %%
test_df['sentiment']=test_df['sentiment'].apply(sentiment_cleaning)

# %%
df.head()
# Out:
#   sentiment                                               text
# 0  positive  democratic party excited to see kamala harris ...
# 1  positive  republican party donald trumps policies are th...
# 2  positive  green party jill steins environmental plans ar...
# 3   neutral  independent robert kennedy offers a fresh pers...
# 4  positive  libertarian party chase olivers libertarian st...

# %%
test_df.head()
# Out:
#   sentiment                                               text
# 0  positive  democratic party democratic party kamala harri...
# 1  positive  republican party republican party donald trump...
# 2  positive  green party green party jill steins environmen...
# 3   neutral  independent independent robert kennedys indepe...
# 4  positive  libertarian party libertarian party chase oliv...

# %%
print(df["sentiment"].unique())
# Out:
# ['positive' 'neutral' 'negative']

# %%
# lest convert df to transformer dataset format

from transformers import BertTokenizerFast, BertForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import numpy as np

# %%
dataset = Dataset.from_pandas(df[['text', 'sentiment']])
dataset = dataset.rename_column("sentiment", "labels")
dataset = dataset.class_encode_column("labels")  # label → class ids
dataset = dataset.train_test_split(test_size=0.2)
# Out:
# Casting to class labels:   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
model_name = "bert-base-uncased"
tokenizer = BertTokenizerFast.from_pretrained(model_name)
# create token embedding
# add sepecial tokens
# add padding
# add masking
# add segment embedding
# add  positonal embedding
model = BertForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def tokenize(batch):
    return tokenizer(batch["text"], padding="max_length", truncation=True, max_length=128)

tokenized = dataset.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/400 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, preds, average='weighted'  # or 'macro' if you want equal class importance
    )
    acc = accuracy_score(labels, preds)

    return {
        "accuracy": acc,
        "f1": f1,
        "precision": precision,
        "recall": recall
    }

# %%
training_args = TrainingArguments(
    output_dir="bert-sentiment-model",
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="epoch",
    num_train_epochs=2,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    learning_rate=2e-5,
    weight_decay=0.01,
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized["train"],
    eval_dataset=tokenized["test"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
trainer.train()
# Out:
# /tmp/ipython-input-56-4230512330.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 23:35, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.508400</td>
#       <td>0.213243</td>
#       <td>0.940000</td>
#       <td>0.943300</td>
#       <td>0.960000</td>
#       <td>0.940000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.152300</td>
#       <td>0.132344</td>
#       <td>0.980000</td>
#       <td>0.980631</td>
#       <td>0.982857</td>
#       <td>0.980000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=0.3303665256500244, metrics={'train_runtime': 1434.4675, 'train_samples_per_second': 0.558, 'train_steps_per_second': 0.07, 'total_flos': 52622683545600.0, 'train_loss': 0.3303665256500244, 'epoch': 2.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='13' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13/13 00:38]
#     </div>
# {'eval_loss': 0.13234449923038483,
#  'eval_accuracy': 0.98,
#  'eval_f1': 0.9806305411470404,
#  'eval_precision': 0.9828571428571428,
#  'eval_recall': 0.98,
#  'eval_runtime': 42.8139,
#  'eval_samples_per_second': 2.336,
#  'eval_steps_per_second': 0.304,
#  'epoch': 2.0}

# %%
# Out:
# Predicted Sentiment: Positive

# %%
correct=0
for row in range(50):
  inputs = tokenizer(test_df['text'][row], return_tensors="pt", truncation=True, padding=True)
  outputs = model(**inputs)
  logits = outputs.logits
  pred = logits.argmax().item()
  sentiment_map = {0: "negative", 1: "neutral", 2: "positive"}
  print("Predicted Sentiment:", sentiment_map[pred], "True Sentiment : ",test_df['sentiment'][row])
  if sentiment_map[pred]==test_df['sentiment'][row]:
    correct+=1
print(correct/50)
# Out:
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: negative True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: negative True Sentiment :  negative
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: negative True Sentiment :  negative
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: negative True Sentiment :  negative
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# Predicted Sentiment: neutral True Sentiment :  neutral
# Predicted Sentiment: positive True Sentiment :  positive
# 0.96
